# %% [markdown]
# <a href="https://colab.research.google.com/github/Keba462/Csi408_/blob/main/Data_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Preparation**
#
# Because the dataset was created for learning purposes i went through data cleaning to make sure the dataset only captures the important features in relation to Covid-19 diagnosis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data =pd.read_excel('/content/drive/MyDrive/Project 408/COVID-19.xlsx')

# %% [markdown]
# Here I looked through the first 10 rows to find out if the corona result column is realistic.

# %%
data.head(10)
# Out:
#     Sno   age  ...  Loss of sense of smell  Corona result
# 0   1.0  20.0  ...                     0.0            0.0
# 1   2.0  19.0  ...                     0.0            0.0
# 2   3.0  55.0  ...                     0.0            1.0
# 3   4.0  40.0  ...                     0.0            2.0
# 4   5.0  33.0  ...                     1.0            2.0
# 5   6.0  51.0  ...                     1.0            2.0
# 6   7.0  80.0  ...                     1.0            2.0
# 7   8.0  52.0  ...                     0.0            1.0
# 8   9.0  53.0  ...                     0.0            1.0
# 9  10.0  54.0  ...                     0.0            1.0
#
# [10 rows x 21 columns]

# %% [markdown]
# Here I looked through the last 10 rows to find out if the corona result column is realistic.

# %%
data.tail(10)
# Out:
#        Sno   age  ...  Loss of sense of smell  Corona result
# 117  118.0  33.0  ...                     0.0            1.0
# 118  119.0  26.0  ...                     0.0            1.0
# 119  120.0  45.0  ...                     1.0            1.0
# 120  121.0  19.0  ...                     0.0            0.0
# 121  122.0  40.0  ...                     1.0            1.0
# 122  123.0  37.0  ...                     0.0            0.0
# 123  124.0  35.0  ...                     0.0            1.0
# 124  125.0  22.0  ...                     1.0            1.0
# 125  126.0  29.0  ...                     1.0            0.0
# 126  127.0  38.0  ...                     0.0            2.0
#
# [10 rows x 21 columns]

# %% [markdown]
# Using the column Sno,I looked through 10 rows in the middle of the dataset to find out if the corona result column is realistic.

# %%
bool_series = data["Sno"].between(70.0, 80.0, inclusive = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   """Entry point for launching an IPython kernel.

# %%
data[bool_series]
# Out:
#      Sno   age  ...  Loss of sense of smell  Corona result
# 69  70.0  21.0  ...                     0.0            1.0
# 70  71.0  32.0  ...                     1.0            0.0
# 71  72.0  23.0  ...                     1.0            0.0
# 72  73.0  35.0  ...                     0.0            1.0
# 73  74.0  27.0  ...                     0.0            1.0
# 74  75.0  31.0  ...                     0.0            0.0
# 75  76.0  29.0  ...                     0.0            1.0
# 76  77.0  37.0  ...                     0.0            2.0
# 77  78.0  25.0  ...                     1.0            1.0
# 78  79.0  33.0  ...                     0.0            0.0
# 79  80.0  26.0  ...                     1.0            2.0
#
# [11 rows x 21 columns]

# %% [markdown]
# Here I dropped the genger colomn because it was not that relevant to the covid result colomn.

# %%
data.drop('gender', inplace=True,axis=1)

# %%
data
# Out:
#        Sno   age  ...  Loss of sense of smell  Corona result
# 0      1.0  20.0  ...                     0.0            0.0
# 1      2.0  19.0  ...                     0.0            0.0
# 2      3.0  55.0  ...                     0.0            1.0
# 3      4.0  40.0  ...                     0.0            2.0
# 4      5.0  33.0  ...                     1.0            2.0
# ..     ...   ...  ...                     ...            ...
# 122  123.0  37.0  ...                     0.0            0.0
# 123  124.0  35.0  ...                     0.0            1.0
# 124  125.0  22.0  ...                     1.0            1.0
# 125  126.0  29.0  ...                     1.0            0.0
# 126  127.0  38.0  ...                     0.0            2.0
#
# [127 rows x 20 columns]

# %%
data.drop('Sno', inplace=True,axis=1)

# %%
data
# Out:
#       age  body temperature  ...  Loss of sense of smell  Corona result
# 0    20.0              98.6  ...                     0.0            0.0
# 1    19.0              99.0  ...                     0.0            0.0
# 2    55.0             102.0  ...                     0.0            1.0
# 3    40.0             100.0  ...                     0.0            2.0
# 4    33.0              99.2  ...                     1.0            2.0
# ..    ...               ...  ...                     ...            ...
# 122  37.0             102.0  ...                     0.0            0.0
# 123  35.0             100.0  ...                     0.0            1.0
# 124  22.0              99.2  ...                     1.0            1.0
# 125  29.0             102.0  ...                     1.0            0.0
# 126  38.0             101.0  ...                     0.0            2.0
#
# [127 rows x 19 columns]

# %%
data.to_excel('/content/drive/MyDrive/Project 408/new.xlsx')

# %%
"""
def convert(x):
  return (x-32) * 1.8
  """

# %%
#data['body temperature']=data['body temperature'].apply(convert)

# %%
#data

# %% [markdown]
# Below i am counting the number of occurances of each unique value in the corona resut column to find out if my dataset is biased
# Loking at the result the data 69 of the individuals are at medium risk, 33 are at low risk and 25 are a high risk the dataset does not seem biased.
# I plotted a bar graph for visualisation.

# %%
data['Corona result'].value_counts().plot(kind='barh')
